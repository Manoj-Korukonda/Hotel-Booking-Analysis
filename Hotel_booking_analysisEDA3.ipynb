# %% [markdown]
# <a href="https://colab.research.google.com/github/mk9652064965/Hotel-Booking-Analysis/blob/main/Hotel_booking_analysisEDA3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things
#
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of cancelation? or which hotel is more preferable to people in particular conditions?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('hotelbookingcsv.csv')

# %%
data
# Out:
#                hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0       Resort Hotel            0  ...           Check-Out               2015-07-01
# 1       Resort Hotel            0  ...           Check-Out               2015-07-01
# 2       Resort Hotel            0  ...           Check-Out               2015-07-02
# 3       Resort Hotel            0  ...           Check-Out               2015-07-02
# 4       Resort Hotel            0  ...           Check-Out               2015-07-03
# ...              ...          ...  ...                 ...                      ...
# 119385    City Hotel            0  ...           Check-Out               2017-09-06
# 119386    City Hotel            0  ...           Check-Out               2017-09-07
# 119387    City Hotel            0  ...           Check-Out               2017-09-07
# 119388    City Hotel            0  ...           Check-Out               2017-09-07
# ...

# %%
data.shape
# Out:
# (119390, 32)

# %%
data.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
data['reservation_status_date']=pd.to_datetime(data['reservation_status_date'],format='%Y-%m-%d %H:%M:%S')

# %%
data
# Out:
#                hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0       Resort Hotel            0  ...           Check-Out               2015-07-01
# 1       Resort Hotel            0  ...           Check-Out               2015-07-01
# 2       Resort Hotel            0  ...           Check-Out               2015-07-02
# 3       Resort Hotel            0  ...           Check-Out               2015-07-02
# 4       Resort Hotel            0  ...           Check-Out               2015-07-03
# ...              ...          ...  ...                 ...                      ...
# 119385    City Hotel            0  ...           Check-Out               2017-09-06
# 119386    City Hotel            0  ...           Check-Out               2017-09-07
# 119387    City Hotel            0  ...           Check-Out               2017-09-07
# 119388    City Hotel            0  ...           Check-Out               2017-09-07
# ...

# %%
data.dtypes
# Out:
# hotel                                     object
# is_canceled                                int64
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                        object
# arrival_date_week_number                   int64
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                 float64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %%
data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
data.drop(['reservation_status_date',],axis=1,inplace=True)
data.head()
# Out:
#           hotel  is_canceled  ...  total_of_special_requests  reservation_status
# 0  Resort Hotel            0  ...                          0           Check-Out
# 1  Resort Hotel            0  ...                          0           Check-Out
# 2  Resort Hotel            0  ...                          0           Check-Out
# 3  Resort Hotel            0  ...                          0           Check-Out
# 4  Resort Hotel            0  ...                          1           Check-Out
#
# [5 rows x 31 columns]

# %%
data['company'].unique()
# Out:
# array([ nan, 110., 113., 270., 178., 240., 154., 144., 307., 268.,  59.,
#        204., 312., 318.,  94., 174., 274., 195., 223., 317., 281., 118.,
#         53., 286.,  12.,  47., 324., 342., 373., 371., 383.,  86.,  82.,
#        218.,  88.,  31., 397., 392., 405., 331., 367.,  20.,  83., 416.,
#         51., 395., 102.,  34.,  84., 360., 394., 457., 382., 461., 478.,
#        386., 112., 486., 421.,   9., 308., 135., 224., 504., 269., 356.,
#        498., 390., 513., 203., 263., 477., 521., 169., 515., 445., 337.,
#        251., 428., 292., 388., 130., 250., 355., 254., 543., 531., 528.,
#         62., 120.,  42.,  81., 116., 530., 103.,  39.,  16.,  92.,  61.,
#        501., 165., 291., 290.,  43., 325., 192., 108., 200., 465., 287.,
#        297., 490., 482., 207., 282., 437., 225., 329., 272.,  28.,  77.,
#        338.,  72., 246., 319., 146., 159., 380., 323., 511., 407., 278.,
#         80., 403., 399.,  14., 137., 343., 346., 347., 349., 289., 351.,
# ...

# %%
data['children'].unique()
# Out:
# array([ 0.,  1.,  2., 10.,  3., nan])

# %%
updated_data = data
updated_data['agent']=updated_data['agent'].fillna(updated_data['agent'].mean())
updated_data['company']=updated_data['company'].fillna(updated_data['company'].mean())
updated_data['children']=updated_data['children'].fillna(updated_data['children'].median())
updated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
updated_data.head()
# Out:
#           hotel  is_canceled  ...  total_of_special_requests  reservation_status
# 0  Resort Hotel            0  ...                          0           Check-Out
# 1  Resort Hotel            0  ...                          0           Check-Out
# 2  Resort Hotel            0  ...                          0           Check-Out
# 3  Resort Hotel            0  ...                          0           Check-Out
# 4  Resort Hotel            0  ...                          1           Check-Out
#
# [5 rows x 31 columns]

# %%
updated_data.isnull().sum()
# Out:
# hotel                               0
# is_canceled                         0
# lead_time                           0
# arrival_date_year                   0
# arrival_date_month                  0
# arrival_date_week_number            0
# arrival_date_day_of_month           0
# stays_in_weekend_nights             0
# stays_in_week_nights                0
# adults                              0
# children                            0
# babies                              0
# meal                                0
# country                           488
# market_segment                      0
# distribution_channel                0
# is_repeated_guest                   0
# previous_cancellations              0
# previous_bookings_not_canceled      0
# reserved_room_type                  0
# assigned_room_type                  0
# booking_changes                     0
# deposit_type                        0
# agent                               0
# company                             0
# ...

# %%
updated_data=updated_data.fillna(updated_data.mode)

# %%
updated_data.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
updated_data.head()
# Out:
#           hotel  is_canceled  ...  total_of_special_requests  reservation_status
# 0  Resort Hotel            0  ...                          0           Check-Out
# 1  Resort Hotel            0  ...                          0           Check-Out
# 2  Resort Hotel            0  ...                          0           Check-Out
# 3  Resort Hotel            0  ...                          0           Check-Out
# 4  Resort Hotel            0  ...                          1           Check-Out
#
# [5 rows x 31 columns]

# %%
updated_data.select_dtypes(include=['int64','float64','Int64']).dtypes
# Out:
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# booking_changes                     int64
# agent                             float64
# company                           float64
# days_in_waiting_list                int64
# adr                               float64
# required_car_parking_spaces         int64
# total_of_special_requests           int64
# dtype: object

# %%
# UNIVARIATIVE ANALYSIS

# %%
#continuous variables

# %%
#segrating variables into groups

arrival_details = ['arrival_date_year','arrival_date_week_number','arrival_date_day_of_month']
stays_details = ['stays_in_weekend_nights','stays_in_week_nights']
people_details = ['adults','children','babies']
cancelation_details = ['previous_cancellations','previous_bookings_not_canceled']
agent_details = ['agent','company']
other_details = ['days_in_waiting_list','required_car_parking_spaces','total_of_special_requests']

# %%
def UVA_numeric(updated_data, var_group):
    size = len(var_group)
    plt.figure(figsize = (7*size,3), dpi = 100)
    for j,i in enumerate(var_group):
        mini = updated_data[i].min()
        maxi = updated_data[i].max()
        mean = updated_data[i].mean()
        median = updated_data[i].median()
        st_dev = updated_data[i].std()
        skew = updated_data[i].skew()
        kurt = updated_data[i].kurtosis()
        points = mean-st_dev, mean+st_dev
        plt.subplot(1,size,j+1)
        sns.kdeplot(updated_data[i], shade=True)
        sns.lineplot(points, [0,0], color = 'black', label = "std_dev")
        sns.scatterplot([mini,maxi], [0,0], color = 'orange', label= "min/max")
        sns.scatterplot([mean], [0], color = 'red', label = "mean")
        sns.scatterplot([median], [0], color = 'blue', label = "median")
        plt.xlabel('{}'.format(i), fontsize = 20)
        plt.ylabel('density')
        plt.title('std_dev = {}; kurtosis = {};\nskew = {}; range = {};\nmean = {}; median = {}'.format((round(points[0],2),round(points[1],2)),
                                                                                        round(kurt,2),
                                                                                        round(skew,2),
                                                                                        (round(mini,2),round(maxi,2)),
                                                                                        round(mean,2),
                                                                                        round(median,2)))

# %%
UVA_numeric(updated_data, arrival_details)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
UVA_numeric(updated_data, stays_details)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
UVA_numeric(updated_data, people_details)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
UVA_numeric(updated_data, cancelation_details)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
UVA_numeric(updated_data, agent_details)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
UVA_numeric(updated_data, other_details)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
#categorical variables

# %%
updated_data.select_dtypes(exclude=['int64','float64','Int64']).dtypes
# Out:
# hotel                   object
# arrival_date_month      object
# meal                    object
# country                 object
# market_segment          object
# distribution_channel    object
# reserved_room_type      object
# assigned_room_type      object
# deposit_type            object
# customer_type           object
# reservation_status      object
# dtype: object

# %%
updated_data['hotel'] = updated_data['hotel'].astype('category')
updated_data['arrival_date_month'] = updated_data['arrival_date_month'].astype('category')
updated_data['meal'] = updated_data['meal'].astype('category')
updated_data['market_segment'] = updated_data['market_segment'].astype('category')
updated_data['distribution_channel'] = updated_data['distribution_channel'].astype('category')
updated_data['reserved_room_type'] = updated_data['reserved_room_type'].astype('category')
updated_data['assigned_room_type'] = updated_data['assigned_room_type'].astype('category')
updated_data['deposit_type'] = updated_data['deposit_type'].astype('category')
updated_data['customer_type'] = updated_data['customer_type'].astype('category')
updated_data['reservation_status'] = updated_data['reservation_status'].astype('category')

# %%
def UVA_category(updated_data, var_group):
    size = len(var_group)
    plt.figure(figsize = (7*size,5), dpi = 100)
    for j,i in enumerate(var_group):
        norm_count = updated_data[i].value_counts(normalize = True)
        n_uni = updated_data[i].nunique()
        plt.subplot(1,size,j+1)
        sns.barplot(norm_count, norm_count.index , order = norm_count.index)
        plt.xlabel('fraction/percent', fontsize = 20)
        plt.ylabel('{}'.format(i), fontsize = 20)
        plt.title('n_uniques = {} \n value counts \n {};'.format(n_uni,norm_count))

# %%
UVA_category(updated_data, ['hotel','arrival_date_month'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
UVA_category(updated_data, ['market_segment','distribution_channel','reserved_room_type','assigned_room_type'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
UVA_category(updated_data, ['deposit_type','customer_type','reservation_status'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
UVA_category(updated_data, ['meal'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#BIVARIATIVE ANALYSIS

# %%
#continuous-continuous variables

# %%
updated_data.head()
# Out:
#           hotel  is_canceled  ...  total_of_special_requests  reservation_status
# 0  Resort Hotel            0  ...                          0           Check-Out
# 1  Resort Hotel            0  ...                          0           Check-Out
# 2  Resort Hotel            0  ...                          0           Check-Out
# 3  Resort Hotel            0  ...                          0           Check-Out
# 4  Resort Hotel            0  ...                          1           Check-Out
#
# [5 rows x 31 columns]

# %%
updated_data.select_dtypes(include=['int64','float64','Int64']).dtypes
# Out:
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# booking_changes                     int64
# agent                             float64
# company                           float64
# days_in_waiting_list                int64
# adr                               float64
# required_car_parking_spaces         int64
# total_of_special_requests           int64
# dtype: object

# %%
numerical = updated_data.select_dtypes(include=['int64','float64','Int64'])[:]
numerical.dtypes
# Out:
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# booking_changes                     int64
# agent                             float64
# company                           float64
# days_in_waiting_list                int64
# adr                               float64
# required_car_parking_spaces         int64
# total_of_special_requests           int64
# dtype: object

# %%
numerical.corr()
# Out:
#                                 is_canceled  ...  total_of_special_requests
# is_canceled                        1.000000  ...                  -0.234658
# lead_time                          0.293123  ...                  -0.095712
# arrival_date_year                  0.016660  ...                   0.108531
# arrival_date_week_number           0.008148  ...                   0.026149
# arrival_date_day_of_month         -0.006130  ...                   0.003062
# stays_in_weekend_nights           -0.001791  ...                   0.072671
# stays_in_week_nights               0.024765  ...                   0.068192
# adults                             0.060017  ...                   0.122884
# children                           0.005036  ...                   0.081736
# babies                            -0.032491  ...                   0.097889
# is_repeated_guest                 -0.084793  ...                   0.013050
# ...

# %%
c=numerical.corr().abs()
s=c.unstack()
so=s.sort_values(kind="quicksort",ascending=False)
so=pd.DataFrame(so,columns=['Pearson correlation'])
so[so['Pearson correlation']<1].head(10)
# Out:
#                                                                Pearson correlation
# arrival_date_year              arrival_date_week_number                   0.540561
# arrival_date_week_number       arrival_date_year                          0.540561
# stays_in_week_nights           stays_in_weekend_nights                    0.498969
# stays_in_weekend_nights        stays_in_week_nights                       0.498969
# previous_bookings_not_canceled is_repeated_guest                          0.418056
# is_repeated_guest              previous_bookings_not_canceled             0.418056
# children                       adr                                        0.324853
# adr                            children                                   0.324853
# is_canceled                    lead_time                                  0.293123
# lead_time                      is_canceled                                0.293123

# %%
# Heat map

# %%
plt.figure(figsize=(36,6),dpi=140)
for j,i in enumerate(['pearson','kendall','spearman']):
    plt.subplot(1,3,j+1)
    correlation = numerical.dropna().corr(method=i)
    sns.heatmap(correlation,linewidth = 2)
    plt.title(i,fontsize=18)

# %%
#categorical-categorical

# %%
updated_data.select_dtypes(exclude=['int64','float64','Int64']).dtypes
# Out:
# hotel                   category
# arrival_date_month      category
# meal                    category
# country                   object
# market_segment          category
# distribution_channel    category
# reserved_room_type      category
# assigned_room_type      category
# deposit_type            category
# customer_type           category
# reservation_status      category
# dtype: object

# %%
def BVA_categorical(updated_data,tar,cat):
    updated_data=updated_data[[cat,tar]][:]
    table=pd.crosstab(updated_data[tar],updated_data[cat])
    f_obs=np.array([table.iloc[0][:].values,
                    table.iloc[1][:].values])
    from scipy.stats import chi2_contingency
    chi,p,dof,expected = chi2_contingency(f_obs)
    if p<0.05:
        sig = True
    else:
        sig = False
    plt.title("p-value = {}\n difference significant? = {}\n".format(round(p,8),sig))
    ax1=updated_data.groupby(cat)[tar].value_counts(normalize=True).unstack()
    ax1.plot(kind='bar',stacked='True',title=str(ax1))
    int_level = updated_data[cat].value_counts()

# %%
BVA_categorical(updated_data,'hotel','arrival_date_month')

# %%
BVA_categorical(updated_data,'hotel','meal')

# %%
BVA_categorical(updated_data,'hotel','distribution_channel')

# %%
BVA_categorical(updated_data,'hotel','market_segment')

# %%
BVA_categorical(updated_data,'hotel','reserved_room_type')

# %%
BVA_categorical(updated_data,'hotel','assigned_room_type')

# %%
BVA_categorical(updated_data,'hotel','deposit_type')

# %%
BVA_categorical(updated_data,'hotel','customer_type')

# %%
BVA_categorical(updated_data,'hotel','reservation_status')
